# %%
from neo4j import GraphDatabase

# %% [markdown]
# ### Neo4j Manual
#
# 1/To create a new node (each note is a distinct unique observation, cannot contain multiple records):
# ```cypher
# CREATE (t:table {col1: 'value1',
#                 col2: 'value2',
#                 col3: 'value3'}) -> the t is the alias of the table name
# ```
# These columns will be accessed via the t.col
#
# 2/To match relationship between nodes
# ```cypher
# MATCH (t2: table2 {id: '......'}),
#         (t3: table3 {id: '......'})
# MERGE(t2)-[:RELATIONSHIP]->(t3); -> define the relationship and the arrow distance
# RETURN t2, t3;
# ```
# or
# ```cypher
# MATCH (t2: table2 {id: '......'}),
#         (t3: table3 {id: '......'})
# MERGE(cl)-[:HAS/INTERACTION {roles: 'interactions'}]->(a2) for more specific interaction
# RETURN t2, t3;
# ```
# 3/Insert data into a node
# ```cypher
# MATCH (t:table {id:'123'})
# SET t.col1 = 'value1'
#     t.col2 = 'value2'
#     t.col3 = 'value3'
# RETURN t
# ```
# 4/Create a node/ relationship if it doesn't exist, or match if it does
# ```cypher
# MERGE (t:table {id: '123'})
# RETURN t
# ```
# 5/Check for existing relationship
# ```cypher
# MATCH (t:table1),
#         (t2:table2)
# EXISTS((t)-[:RELATES/WITH]->(t2))
# ```
# 6/Delete
# ```cypher
# DELETE n
# ```
# or
# ```cypher
# MATCH (n)
# DETACH DELETE n;
# ```
# to delete all
#
#
# 7/Query
# ```cypher
# MATCH (t:table1) WHERE t.col1 = '....'
# ORDER BY t.col1 DESC
# RETURN t as table1
# ```
# 8/Query the Viz
#
# //Show all nodes and relationship
# ```cypher
# MATCH (n)-[r]->(m)
# RETURN n, r, m;
# ```
# // Show all nodes but relationship
# ```cypher
# MATCH (n)
# RETURN n;
# ```
# // Show Schema (Labels + relation type)
# ```cypher
# CALL db.schema.visualization();
# ```
# // Sample down return
# ```cypher
# MATCH (n)-[r]->(m)
# RETURN n, r, m
# LIMIT 200; //limit to 200 nodes
# ```

# %%
URI = "neo4j+s://4854812f.databases.neo4j.io"
AUTH = ("neo4j", "Y3J7Nh_bl6GgzcQH1SusosMAClb3g0fV0900dQ4f6aU")

user = 'neo4j'

# %%
def query_neo4j(query: str, **params):
    """
    Function to query the Neo4j db, used for Query and retrieving data
    """
    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        driver.verify_connectivity()
        records, summary, keys = driver.execute_query(
            query,
            **params,  #Expect params to be in dictionary format
            database="neo4j"
        )
        return [record.data() for record in records]

def dml_ddl_neo4j(query: str, **params):
    """
    Function for DDL and DML in Neo4j database
    """    
    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        driver.verify_connectivity()
        records, summary, keys = driver.execute_query(
            query,
            **params,   #Expect params to be in dictionary format
            database="neo4j"
        )

        print("Created {nodes_created} nodes, {rels_created} rels in {time} ms.".format(
            nodes_created=summary.counters.nodes_created,
            rels_created=summary.counters.relationships_created,
            time=summary.result_available_after
        ))

# %%
'''
Run this in .cypher file after connecting env to Neo4j and open query results tab in terminal to see the result

MATCH (n: Test_3)-[r]->(m: Test_3) RETURN n, r, m
'''

#Don't do this for querying, only do it for DDL/DML operations

query_neo4j('MATCH (n: Test_3)-[r]->(m: Test_3) RETURN n, r, m')
# Out:
# [{'n': {'amendment_history': 'None',
#    'law_id': '256/2025/NĐ-CP',
#    'issuer_department': 'Chính Phủ',
#    'issue_date': '03/10/2025',
#    'jurisdiction_scope': 'National',
#    'location': 'Hà Nội',
#    'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#    'issuer': 'Unknown',
#    'document_type': 'Nghị Định'},
#   'r': ({'amendment_history': 'None',
#     'law_id': '256/2025/NĐ-CP',
#     'issuer_department': 'Chính Phủ',
#     'issue_date': '03/10/2025',
#     'jurisdiction_scope': 'National',
#     'location': 'Hà Nội',
#     'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#     'issuer': 'Unknown',
#     'document_type': 'Nghị Định'},
#    'Pursuant',
#    {'law_id': '63/2025/QH15'}),
#   'm': {'law_id': '63/2025/QH15'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I',
#    'text': 'QUY ĐỊNH CHUNG',
#    'title': 'Chương I'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I',
#     'text': 'QUY ĐỊNH CHUNG',
#     'title': 'Chương I'},
#    'HAS_CLAUSE',
#    {'id': '256/2025/NĐ-CP_chapter_I_C1',
#     'text': 'Điều 1. Phạm vi điều chỉnh'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C1',
#    'text': 'Điều 1. Phạm vi điều chỉnh'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C1',
#    'text': 'Điều 1. Phạm vi điều chỉnh'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C1',
#     'text': 'Điều 1. Phạm vi điều chỉnh'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#     'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#    'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'}},
#  {'n': {'amendment_history': 'None',
#    'law_id': '256/2025/NĐ-CP',
#    'issuer_department': 'Chính Phủ',
#    'issue_date': '03/10/2025',
#    'jurisdiction_scope': 'National',
#    'location': 'Hà Nội',
#    'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#    'issuer': 'Unknown',
#    'document_type': 'Nghị Định'},
#   'r': ({'amendment_history': 'None',
#     'law_id': '256/2025/NĐ-CP',
#     'issuer_department': 'Chính Phủ',
#     'issue_date': '03/10/2025',
#     'jurisdiction_scope': 'National',
#     'location': 'Hà Nội',
#     'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#     'issuer': 'Unknown',
#     'document_type': 'Nghị Định'},
#    'Pursuant',
#    {'amendment_history': 'None',
#     'law_id': '64/2020/QH14',
#     'issuer_department': 'Quốc Hội',
#     'issue_date': '18/06/2020',
#     'jurisdiction_scope': 'National',
#     'location': 'Hà Nội',
#     'title': 'Luật Đầu Tư Theo Phương',
#     'issuer': 'Nguyễn Thị Kim Ngân',
#     'document_type': 'Luật'}),
#   'm': {'amendment_history': 'None',
#    'law_id': '64/2020/QH14',
#    'issuer_department': 'Quốc Hội',
#    'issue_date': '18/06/2020',
#    'jurisdiction_scope': 'National',
#    'location': 'Hà Nội',
#    'title': 'Luật Đầu Tư Theo Phương',
#    'issuer': 'Nguyễn Thị Kim Ngân',
#    'document_type': 'Luật'}},
#  {'n': {'amendment_history': 'None',
#    'law_id': '256/2025/NĐ-CP',
#    'issuer_department': 'Chính Phủ',
#    'issue_date': '03/10/2025',
#    'jurisdiction_scope': 'National',
#    'location': 'Hà Nội',
#    'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#    'issuer': 'Unknown',
#    'document_type': 'Nghị Định'},
#   'r': ({'amendment_history': 'None',
#     'law_id': '256/2025/NĐ-CP',
#     'issuer_department': 'Chính Phủ',
#     'issue_date': '03/10/2025',
#     'jurisdiction_scope': 'National',
#     'location': 'Hà Nội',
#     'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#     'issuer': 'Unknown',
#     'document_type': 'Nghị Định'},
#    'Pursuant',
#    {'law_id': '57/2024/QH15'}),
#   'm': {'law_id': '57/2024/QH15'}},
#  {'n': {'amendment_history': 'None',
#    'law_id': '256/2025/NĐ-CP',
#    'issuer_department': 'Chính Phủ',
#    'issue_date': '03/10/2025',
#    'jurisdiction_scope': 'National',
#    'location': 'Hà Nội',
#    'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#    'issuer': 'Unknown',
#    'document_type': 'Nghị Định'},
#   'r': ({'amendment_history': 'None',
#     'law_id': '256/2025/NĐ-CP',
#     'issuer_department': 'Chính Phủ',
#     'issue_date': '03/10/2025',
#     'jurisdiction_scope': 'National',
#     'location': 'Hà Nội',
#     'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#     'issuer': 'Unknown',
#     'document_type': 'Nghị Định'},
#    'Pursuant',
#    {'amendment_history': 'None',
#     'law_id': '90/2025/QH15',
#     'issuer_department': 'Quốc Hội',
#     'issue_date': '25/06/2025',
#     'jurisdiction_scope': 'National',
#     'location': 'Hà Nội',
#     'title': 'Luật Sửa Đổi , Bổ',
#     'issuer': 'Trần Thanh Mẫn',
#     'document_type': 'Luật'}),
#   'm': {'amendment_history': 'None',
#    'law_id': '90/2025/QH15',
#    'issuer_department': 'Quốc Hội',
#    'issue_date': '25/06/2025',
#    'jurisdiction_scope': 'National',
#    'location': 'Hà Nội',
#    'title': 'Luật Sửa Đổi , Bổ',
#    'issuer': 'Trần Thanh Mẫn',
#    'document_type': 'Luật'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#    'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#     'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C1_P1_SPa',
#     'text': 'a) Điều 11 về quy trình thực hiện dự án BT;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C1_P1_SPa',
#    'text': 'a) Điều 11 về quy trình thực hiện dự án BT;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#    'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#     'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C1_P1_SPb',
#     'text': 'b) Điều 42 về phương pháp và tiêu chuẩn đánh giá hồ sơ dự thầu;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C1_P1_SPb',
#    'text': 'b) Điều 42 về phương pháp và tiêu chuẩn đánh giá hồ sơ dự thầu;'}},
#  {'n': {'amendment_history': 'None',
#    'law_id': '256/2025/NĐ-CP',
#    'issuer_department': 'Chính Phủ',
#    'issue_date': '03/10/2025',
#    'jurisdiction_scope': 'National',
#    'location': 'Hà Nội',
#    'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#    'issuer': 'Unknown',
#    'document_type': 'Nghị Định'},
#   'r': ({'amendment_history': 'None',
#     'law_id': '256/2025/NĐ-CP',
#     'issuer_department': 'Chính Phủ',
#     'issue_date': '03/10/2025',
#     'jurisdiction_scope': 'National',
#     'location': 'Hà Nội',
#     'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#     'issuer': 'Unknown',
#     'document_type': 'Nghị Định'},
#    'HAS_CHAPTER',
#    {'id': '256/2025/NĐ-CP_chapter_I',
#     'text': 'QUY ĐỊNH CHUNG',
#     'title': 'Chương I'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I',
#    'text': 'QUY ĐỊNH CHUNG',
#    'title': 'Chương I'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#    'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#     'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C1_P1_SPc',
#     'text': 'c) Điểm a khoản 2a Điều 45 về dự án BT thanh toán bằng quỹ đất;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C1_P1_SPc',
#    'text': 'c) Điểm a khoản 2a Điều 45 về dự án BT thanh toán bằng quỹ đất;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#    'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C1_P1',
#     'text': '1. Nghị định này quy định chi tiết một số điều của Luật Đầu tư theo phương thức đối tác công tư về\nviệc thực hiện dự án áp dụng loại hợp đồng Xây dựng - Chuyển giao (dự án BT), gồm:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C1_P1_SPd',
#     'text': 'd) Điểm b khoản 2a Điều 45 về dự án BT thanh toán bằng ngân sách nhà nước.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C1_P1_SPd',
#    'text': 'd) Điểm b khoản 2a Điều 45 về dự án BT thanh toán bằng ngân sách nhà nước.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C1',
#    'text': 'Điều 1. Phạm vi điều chỉnh'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C1',
#     'text': 'Điều 1. Phạm vi điều chỉnh'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C1_P2',
#     'text': '2. Nghị định này không áp dụng đối với dự án BT không yêu cầu thanh toán quy định tại điểm c khoản\n2a Điều 45 của Luật Đầu tư theo phương thức đối tác công tư.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C1_P2',
#    'text': '2. Nghị định này không áp dụng đối với dự án BT không yêu cầu thanh toán quy định tại điểm c khoản\n2a Điều 45 của Luật Đầu tư theo phương thức đối tác công tư.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C1',
#    'text': 'Điều 1. Phạm vi điều chỉnh'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C1',
#     'text': 'Điều 1. Phạm vi điều chỉnh'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C1_P3',
#     'text': '3. Cơ chế quản lý tài chính dự án, lãi vay sau thời gian xây dựng đối với dự án BT thanh toán bằng quỹ\nđất thực hiện theo quy định của Chính phủ quy định cơ chế quản lý tài chính dự án đầu tư theo phương\nthức đối tác công tư và cơ chế thanh toán, quyết toán đối với dự án áp dụng loại hợp đồng BT.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C1_P3',
#    'text': '3. Cơ chế quản lý tài chính dự án, lãi vay sau thời gian xây dựng đối với dự án BT thanh toán bằng quỹ\nđất thực hiện theo quy định của Chính phủ quy định cơ chế quản lý tài chính dự án đầu tư theo phương\nthức đối tác công tư và cơ chế thanh toán, quyết toán đối với dự án áp dụng loại hợp đồng BT.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I',
#    'text': 'QUY ĐỊNH CHUNG',
#    'title': 'Chương I'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I',
#     'text': 'QUY ĐỊNH CHUNG',
#     'title': 'Chương I'},
#    'HAS_CLAUSE',
#    {'id': '256/2025/NĐ-CP_chapter_I_C2',
#     'text': 'Điều 2. Đối tượng áp dụng\nNghị định này áp dụng đối với tổ chức, cá nhân tham gia hoặc có liên quan đến việc thực hiện dự án\nBT quy định tại khoản 1 Điều 1 của Nghị định này.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C2',
#    'text': 'Điều 2. Đối tượng áp dụng\nNghị định này áp dụng đối với tổ chức, cá nhân tham gia hoặc có liên quan đến việc thực hiện dự án\nBT quy định tại khoản 1 Điều 1 của Nghị định này.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I',
#    'text': 'QUY ĐỊNH CHUNG',
#    'title': 'Chương I'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I',
#     'text': 'QUY ĐỊNH CHUNG',
#     'title': 'Chương I'},
#    'HAS_CLAUSE',
#    {'id': '256/2025/NĐ-CP_chapter_I_C3',
#     'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C3',
#    'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C3',
#    'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C3',
#     'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C3_P1',
#     'text': '1. Quỹ đất thanh toán  là khu đất, thửa đất, quỹ đất đáp ứng điều kiện quy định tại khoản 2 Điều 6 của\nNghị định này được cơ quan có thẩm quyền xác định để thanh toán cho nhà đầu tư, doanh nghiệp dự án\n(nếu có) thực hiện dự án BT thanh toán bằng quỹ đất.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C3_P1',
#    'text': '1. Quỹ đất thanh toán  là khu đất, thửa đất, quỹ đất đáp ứng điều kiện quy định tại khoản 2 Điều 6 của\nNghị định này được cơ quan có thẩm quyền xác định để thanh toán cho nhà đầu tư, doanh nghiệp dự án\n(nếu có) thực hiện dự án BT thanh toán bằng quỹ đất.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C3',
#    'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C3',
#     'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C3_P2',
#     'text': '2. Dự án đối ứng là một hoặc các dự án được nhà đầu tư, doanh nghiệp dự án thực hiện tại quỹ đất\nthanh toán theo hợp đồng dự án BT.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C3_P2',
#    'text': '2. Dự án đối ứng là một hoặc các dự án được nhà đầu tư, doanh nghiệp dự án thực hiện tại quỹ đất\nthanh toán theo hợp đồng dự án BT.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C3',
#    'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C3',
#     'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C3_P3',
#     'text': '3. Giá trị chênh lệch thực tế  là phần chênh lệch giữa giá trị quỹ đất thanh toán tại thời điểm thanh toán\nquỹ đất và giá trị công trình dự án BT quyết toán hoặc giá trị khối lượng nghiệm thu hoặc giá trị\nnghiệm thu hoàn thành hạng mục công trình dự án BT.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C3_P3',
#    'text': '3. Giá trị chênh lệch thực tế  là phần chênh lệch giữa giá trị quỹ đất thanh toán tại thời điểm thanh toán\nquỹ đất và giá trị công trình dự án BT quyết toán hoặc giá trị khối lượng nghiệm thu hoặc giá trị\nnghiệm thu hoàn thành hạng mục công trình dự án BT.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C3',
#    'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C3',
#     'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C3_P4',
#     'text': '4. Tỷ lệ gia tăng nộp ngân sách nhà nước  là tỷ lệ nhà đầu tư đề xuất nhằm xác định giá trị gia tăng nộp\nngân sách nhà nước đối với quỹ đất thanh toán.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C3_P4',
#    'text': '4. Tỷ lệ gia tăng nộp ngân sách nhà nước  là tỷ lệ nhà đầu tư đề xuất nhằm xác định giá trị gia tăng nộp\nngân sách nhà nước đối với quỹ đất thanh toán.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C3',
#    'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C3',
#     'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C3_P5',
#     'text': '5. Giá trị gia tăng nộp ngân sách nhà nước  được xác định bằng tỷ lệ gia tăng nộp ngân sách nhà nước\ndo nhà đầu tư đề xuất nhân với giá trị chênh lệch thực tế.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C3_P5',
#    'text': '5. Giá trị gia tăng nộp ngân sách nhà nước  được xác định bằng tỷ lệ gia tăng nộp ngân sách nhà nước\ndo nhà đầu tư đề xuất nhân với giá trị chênh lệch thực tế.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C3',
#    'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C3',
#     'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C3_P6',
#     'text': '6. Quỹ đất, tài sản công đấu giá  là khu đất, thửa đất, quỹ đất hoặc tài sản công được cơ quan có thẩm\nquyền xác định theo quy định của pháp luật về đất đai, pháp luật về quản lý, sử dụng tài sản công để tổ\nchức đấu giá nhằm tạo nguồn thu ngân sách nhà nước thanh toán cho nhà đầu tư thực hiện dự án BT.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C3_P6',
#    'text': '6. Quỹ đất, tài sản công đấu giá  là khu đất, thửa đất, quỹ đất hoặc tài sản công được cơ quan có thẩm\nquyền xác định theo quy định của pháp luật về đất đai, pháp luật về quản lý, sử dụng tài sản công để tổ\nchức đấu giá nhằm tạo nguồn thu ngân sách nhà nước thanh toán cho nhà đầu tư thực hiện dự án BT.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C3',
#    'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C3',
#     'text': 'Điều 3. Giải thích từ ngữ\nTrong Nghị định này, các từ ngữ sau đây được hiểu như sau:'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C3_P7',
#     'text': '7. Giá trị công trình dự án BT quyết toán  là giá trị công trình dự án BT được quyết toán dự án hoàn\nthành theo quy định của pháp luật về xây dựng và pháp luật có liên quan.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C3_P7',
#    'text': '7. Giá trị công trình dự án BT quyết toán  là giá trị công trình dự án BT được quyết toán dự án hoàn\nthành theo quy định của pháp luật về xây dựng và pháp luật có liên quan.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I',
#    'text': 'QUY ĐỊNH CHUNG',
#    'title': 'Chương I'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I',
#     'text': 'QUY ĐỊNH CHUNG',
#     'title': 'Chương I'},
#    'HAS_CLAUSE',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4',
#     'text': 'Điều 4. Quy trình thực hiện dự án BT'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4',
#    'text': 'Điều 4. Quy trình thực hiện dự án BT'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4',
#    'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4',
#     'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P1',
#     'text': '1. Đối với dự án BT thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, quy trình thực hiện\nnhư sau:'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P1',
#    'text': '1. Đối với dự án BT thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, quy trình thực hiện\nnhư sau:'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P1',
#    'text': '1. Đối với dự án BT thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, quy trình thực hiện\nnhư sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P1',
#     'text': '1. Đối với dự án BT thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, quy trình thực hiện\nnhư sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P1_SPa',
#     'text': 'a) Lập, thẩm định báo cáo nghiên cứu tiền khả thi, trình Quốc hội quyết định chủ trương đầu tư;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P1_SPa',
#    'text': 'a) Lập, thẩm định báo cáo nghiên cứu tiền khả thi, trình Quốc hội quyết định chủ trương đầu tư;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P1',
#    'text': '1. Đối với dự án BT thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, quy trình thực hiện\nnhư sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P1',
#     'text': '1. Đối với dự án BT thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, quy trình thực hiện\nnhư sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P1_SPb',
#     'text': 'b) Lập, thẩm định báo cáo nghiên cứu khả thi, phê duyệt dự án;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P1_SPb',
#    'text': 'b) Lập, thẩm định báo cáo nghiên cứu khả thi, phê duyệt dự án;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P1',
#    'text': '1. Đối với dự án BT thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, quy trình thực hiện\nnhư sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P1',
#     'text': '1. Đối với dự án BT thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, quy trình thực hiện\nnhư sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P1_SPc',
#     'text': 'c) Lựa chọn nhà đầu tư; lập, thẩm định, phê duyệt thiết kế kỹ thuật (trong trường hợp thiết kế ba bước)\nhoặc thiết kế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán; ký kết và thực hiện hợp\nđồng dự án.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P1_SPc',
#    'text': 'c) Lựa chọn nhà đầu tư; lập, thẩm định, phê duyệt thiết kế kỹ thuật (trong trường hợp thiết kế ba bước)\nhoặc thiết kế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán; ký kết và thực hiện hợp\nđồng dự án.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4',
#    'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4',
#     'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P2',
#     'text': '2. Đối với dự án BT thanh toán bằng ngân sách nhà nước hoặc dự án BT kết hợp thanh toán bằng quỹ\nđất và ngân sách nhà nước, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy trình thực hiện\nnhư sau:'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P2',
#    'text': '2. Đối với dự án BT thanh toán bằng ngân sách nhà nước hoặc dự án BT kết hợp thanh toán bằng quỹ\nđất và ngân sách nhà nước, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy trình thực hiện\nnhư sau:'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P2',
#    'text': '2. Đối với dự án BT thanh toán bằng ngân sách nhà nước hoặc dự án BT kết hợp thanh toán bằng quỹ\nđất và ngân sách nhà nước, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy trình thực hiện\nnhư sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P2',
#     'text': '2. Đối với dự án BT thanh toán bằng ngân sách nhà nước hoặc dự án BT kết hợp thanh toán bằng quỹ\nđất và ngân sách nhà nước, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy trình thực hiện\nnhư sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P2_SPa',
#     'text': 'a) Lập, thẩm định báo cáo đề xuất chủ trương đầu tư, quyết định chủ trương đầu tư;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P2_SPa',
#    'text': 'a) Lập, thẩm định báo cáo đề xuất chủ trương đầu tư, quyết định chủ trương đầu tư;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P2',
#    'text': '2. Đối với dự án BT thanh toán bằng ngân sách nhà nước hoặc dự án BT kết hợp thanh toán bằng quỹ\nđất và ngân sách nhà nước, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy trình thực hiện\nnhư sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P2',
#     'text': '2. Đối với dự án BT thanh toán bằng ngân sách nhà nước hoặc dự án BT kết hợp thanh toán bằng quỹ\nđất và ngân sách nhà nước, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy trình thực hiện\nnhư sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P2_SPb',
#     'text': 'b) Lập, thẩm định báo cáo nghiên cứu khả thi hoặc báo cáo kinh tế - kỹ thuật đầu tư xây dựng đối với\ndự án BT thuộc trường hợp lập báo cáo kinh tế - kỹ thuật đầu tư xây dựng; phê duyệt dự án;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P2_SPb',
#    'text': 'b) Lập, thẩm định báo cáo nghiên cứu khả thi hoặc báo cáo kinh tế - kỹ thuật đầu tư xây dựng đối với\ndự án BT thuộc trường hợp lập báo cáo kinh tế - kỹ thuật đầu tư xây dựng; phê duyệt dự án;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P2',
#    'text': '2. Đối với dự án BT thanh toán bằng ngân sách nhà nước hoặc dự án BT kết hợp thanh toán bằng quỹ\nđất và ngân sách nhà nước, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy trình thực hiện\nnhư sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P2',
#     'text': '2. Đối với dự án BT thanh toán bằng ngân sách nhà nước hoặc dự án BT kết hợp thanh toán bằng quỹ\nđất và ngân sách nhà nước, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy trình thực hiện\nnhư sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P2_SPc',
#     'text': 'c) Lựa chọn nhà đầu tư; lập, thẩm định, phê duyệt thiết kế kỹ thuật (trong trường hợp thiết kế ba bước)\nhoặc thiết kế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán; ký kết và thực hiện hợp\nđồng dự án.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P2_SPc',
#    'text': 'c) Lựa chọn nhà đầu tư; lập, thẩm định, phê duyệt thiết kế kỹ thuật (trong trường hợp thiết kế ba bước)\nhoặc thiết kế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán; ký kết và thực hiện hợp\nđồng dự án.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4',
#    'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4',
#     'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P3',
#     'text': '3. Đối với dự án BT thanh toán bằng quỹ đất, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy\ntrình thực hiện như sau:'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P3',
#    'text': '3. Đối với dự án BT thanh toán bằng quỹ đất, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy\ntrình thực hiện như sau:'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P3',
#    'text': '3. Đối với dự án BT thanh toán bằng quỹ đất, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy\ntrình thực hiện như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P3',
#     'text': '3. Đối với dự án BT thanh toán bằng quỹ đất, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy\ntrình thực hiện như sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P3_SPa',
#     'text': 'a) Lập, thẩm định báo cáo nghiên cứu khả thi hoặc báo cáo kinh tế - kỹ thuật đầu tư xây dựng đối với\ndự án BT thuộc trường hợp lập báo cáo kinh tế - kỹ thuật đầu tư xây dựng; phê duyệt dự án;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P3_SPa',
#    'text': 'a) Lập, thẩm định báo cáo nghiên cứu khả thi hoặc báo cáo kinh tế - kỹ thuật đầu tư xây dựng đối với\ndự án BT thuộc trường hợp lập báo cáo kinh tế - kỹ thuật đầu tư xây dựng; phê duyệt dự án;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P3',
#    'text': '3. Đối với dự án BT thanh toán bằng quỹ đất, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy\ntrình thực hiện như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P3',
#     'text': '3. Đối với dự án BT thanh toán bằng quỹ đất, trừ dự án quy định tại khoản 1 và khoản 4 Điều này, quy\ntrình thực hiện như sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P3_SPb',
#     'text': 'b) Lựa chọn nhà đầu tư; lập, thẩm định, phê duyệt thiết kế kỹ thuật (trong trường hợp thiết kế ba bước)\nhoặc thiết kế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán; ký kết và thực hiện hợp\nđồng dự án.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P3_SPb',
#    'text': 'b) Lựa chọn nhà đầu tư; lập, thẩm định, phê duyệt thiết kế kỹ thuật (trong trường hợp thiết kế ba bước)\nhoặc thiết kế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán; ký kết và thực hiện hợp\nđồng dự án.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4',
#    'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4',
#     'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P4',
#     'text': '4. Đối với dự án BT thanh toán bằng quỹ đất do nhà đầu tư đề xuất thuộc trường hợp chỉ định nhà đầu\ntư theo quy định tại Luật Đầu tư theo phương thức đối tác công tư, trừ dự án quy định tại khoản 1 Điều\nnày, quy trình thực hiện như sau:'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P4',
#    'text': '4. Đối với dự án BT thanh toán bằng quỹ đất do nhà đầu tư đề xuất thuộc trường hợp chỉ định nhà đầu\ntư theo quy định tại Luật Đầu tư theo phương thức đối tác công tư, trừ dự án quy định tại khoản 1 Điều\nnày, quy trình thực hiện như sau:'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P4',
#    'text': '4. Đối với dự án BT thanh toán bằng quỹ đất do nhà đầu tư đề xuất thuộc trường hợp chỉ định nhà đầu\ntư theo quy định tại Luật Đầu tư theo phương thức đối tác công tư, trừ dự án quy định tại khoản 1 Điều\nnày, quy trình thực hiện như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P4',
#     'text': '4. Đối với dự án BT thanh toán bằng quỹ đất do nhà đầu tư đề xuất thuộc trường hợp chỉ định nhà đầu\ntư theo quy định tại Luật Đầu tư theo phương thức đối tác công tư, trừ dự án quy định tại khoản 1 Điều\nnày, quy trình thực hiện như sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P4_SPa',
#     'text': 'a) Nhà đầu tư đề xuất dự án, lập báo cáo nghiên cứu khả thi kèm theo hồ sơ năng lực và dự thảo hợp\nđồng;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P4_SPa',
#    'text': 'a) Nhà đầu tư đề xuất dự án, lập báo cáo nghiên cứu khả thi kèm theo hồ sơ năng lực và dự thảo hợp\nđồng;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P4',
#    'text': '4. Đối với dự án BT thanh toán bằng quỹ đất do nhà đầu tư đề xuất thuộc trường hợp chỉ định nhà đầu\ntư theo quy định tại Luật Đầu tư theo phương thức đối tác công tư, trừ dự án quy định tại khoản 1 Điều\nnày, quy trình thực hiện như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P4',
#     'text': '4. Đối với dự án BT thanh toán bằng quỹ đất do nhà đầu tư đề xuất thuộc trường hợp chỉ định nhà đầu\ntư theo quy định tại Luật Đầu tư theo phương thức đối tác công tư, trừ dự án quy định tại khoản 1 Điều\nnày, quy trình thực hiện như sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P4_SPb',
#     'text': 'b) Cơ quan có thẩm quyền tổ chức thẩm định báo cáo nghiên cứu khả thi, phê duyệt dự án và kết quả\nchỉ định nhà đầu tư, dự thảo hợp đồng; thiết kế kỹ thuật (trong trường hợp thiết kế ba bước) hoặc thiết\nkế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P4_SPb',
#    'text': 'b) Cơ quan có thẩm quyền tổ chức thẩm định báo cáo nghiên cứu khả thi, phê duyệt dự án và kết quả\nchỉ định nhà đầu tư, dự thảo hợp đồng; thiết kế kỹ thuật (trong trường hợp thiết kế ba bước) hoặc thiết\nkế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4_P4',
#    'text': '4. Đối với dự án BT thanh toán bằng quỹ đất do nhà đầu tư đề xuất thuộc trường hợp chỉ định nhà đầu\ntư theo quy định tại Luật Đầu tư theo phương thức đối tác công tư, trừ dự án quy định tại khoản 1 Điều\nnày, quy trình thực hiện như sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4_P4',
#     'text': '4. Đối với dự án BT thanh toán bằng quỹ đất do nhà đầu tư đề xuất thuộc trường hợp chỉ định nhà đầu\ntư theo quy định tại Luật Đầu tư theo phương thức đối tác công tư, trừ dự án quy định tại khoản 1 Điều\nnày, quy trình thực hiện như sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P4_SPc',
#     'text': 'c) Ký kết và thực hiện hợp đồng dự án.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P4_SPc',
#    'text': 'c) Ký kết và thực hiện hợp đồng dự án.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4',
#    'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4',
#     'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P5',
#     'text': '5. Cơ quan có thẩm quyền được thực hiện thủ tục thẩm định, phê duyệt thiết kế kỹ thuật (trong trường\nhợp thiết kế ba bước) hoặc thiết kế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán của\ncông trình dự án BT quy định tại điểm c khoản 1, điểm c khoản 2, điểm b khoản 3, điểm b khoản 4\nĐiều này đồng thời với quá trình lựa chọn nhà đầu tư nhưng phải bảo đảm hợp đồng dự án BT được ký\nkết trên cơ sở thiết kế, dự toán đã được phê duyệt.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P5',
#    'text': '5. Cơ quan có thẩm quyền được thực hiện thủ tục thẩm định, phê duyệt thiết kế kỹ thuật (trong trường\nhợp thiết kế ba bước) hoặc thiết kế bản vẽ thi công (trong trường hợp thiết kế hai bước) và dự toán của\ncông trình dự án BT quy định tại điểm c khoản 1, điểm c khoản 2, điểm b khoản 3, điểm b khoản 4\nĐiều này đồng thời với quá trình lựa chọn nhà đầu tư nhưng phải bảo đảm hợp đồng dự án BT được ký\nkết trên cơ sở thiết kế, dự toán đã được phê duyệt.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_I_C4',
#    'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_I_C4',
#     'text': 'Điều 4. Quy trình thực hiện dự án BT'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_I_C4_P6',
#     'text': '6. Trường hợp dự án BT quy định tại khoản 3 và khoản 4 Điều này cần thực hiện thủ tục quyết định\nchủ trương đầu tư để làm căn cứ quyết định chủ trương chuyển mục đích sử dụng đất lúa theo quy định\ncủa pháp luật về đất đai, quyết định chủ trương chuyển mục đích sử dụng đất rừng theo quy định của\npháp luật về lâm nghiệp và thực hiện thủ tục khác theo quy định của pháp luật có liên quan thì thực\nhiện lập, thẩm định báo cáo đề xuất chủ trương đầu tư, quyết định chủ trương đầu tư theo quy định tại\nđiểm a khoản 2 Điều này. Thẩm quyền quyết định chủ trương đầu tư dự án BT trong trường hợp này\nthực hiện như quy định đối với dự án BT thanh toán bằng ngân sách nhà nước.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_I_C4_P6',
#    'text': '6. Trường hợp dự án BT quy định tại khoản 3 và khoản 4 Điều này cần thực hiện thủ tục quyết định\nchủ trương đầu tư để làm căn cứ quyết định chủ trương chuyển mục đích sử dụng đất lúa theo quy định\ncủa pháp luật về đất đai, quyết định chủ trương chuyển mục đích sử dụng đất rừng theo quy định của\npháp luật về lâm nghiệp và thực hiện thủ tục khác theo quy định của pháp luật có liên quan thì thực\nhiện lập, thẩm định báo cáo đề xuất chủ trương đầu tư, quyết định chủ trương đầu tư theo quy định tại\nđiểm a khoản 2 Điều này. Thẩm quyền quyết định chủ trương đầu tư dự án BT trong trường hợp này\nthực hiện như quy định đối với dự án BT thanh toán bằng ngân sách nhà nước.'}},
#  {'n': {'amendment_history': 'None',
#    'law_id': '256/2025/NĐ-CP',
#    'issuer_department': 'Chính Phủ',
#    'issue_date': '03/10/2025',
#    'jurisdiction_scope': 'National',
#    'location': 'Hà Nội',
#    'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#    'issuer': 'Unknown',
#    'document_type': 'Nghị Định'},
#   'r': ({'amendment_history': 'None',
#     'law_id': '256/2025/NĐ-CP',
#     'issuer_department': 'Chính Phủ',
#     'issue_date': '03/10/2025',
#     'jurisdiction_scope': 'National',
#     'location': 'Hà Nội',
#     'title': 'Nghị Định Quy Định Chi Tiết Về Việc Thực Hiện Dự Ánáp Dụng Loại Hợp Đồng Xây Dựng - Chuyển Giao',
#     'issuer': 'Unknown',
#     'document_type': 'Nghị Định'},
#    'HAS_CHAPTER',
#    {'id': '256/2025/NĐ-CP_chapter_II',
#     'text': 'CHUẨN BỊ DỰ ÁN',
#     'title': 'Chương II'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II',
#    'text': 'CHUẨN BỊ DỰ ÁN',
#    'title': 'Chương II'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II',
#    'text': 'CHUẨN BỊ DỰ ÁN',
#    'title': 'Chương II'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II',
#     'text': 'CHUẨN BỊ DỰ ÁN',
#     'title': 'Chương II'},
#    'HAS_CLAUSE',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5',
#     'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5',
#    'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5',
#    'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5',
#     'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P1',
#     'text': '1. Đối với dự án thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, trình tự, thủ tục lập,\nthẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư, quyết định chủ trương\nđầu tư dự án BT thực hiện theo quy định tại Điều 13 và Điều 14 của Luật Đầu tư theo phương thức đối\ntác công tư và quy định của Chính phủ về trình tự, thủ tục thẩm định dự án quan trọng quốc gia.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P1',
#    'text': '1. Đối với dự án thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội, trình tự, thủ tục lập,\nthẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư, quyết định chủ trương\nđầu tư dự án BT thực hiện theo quy định tại Điều 13 và Điều 14 của Luật Đầu tư theo phương thức đối\ntác công tư và quy định của Chính phủ về trình tự, thủ tục thẩm định dự án quan trọng quốc gia.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5',
#    'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5',
#     'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P2',
#     'text': '2. Đối với dự án không thuộc trường hợp quy định tại khoản 1 Điều này, trình tự, thủ tục lập, thẩm định\nbáo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư, quyết định chủ trương đầu tư dự án\nBT thực hiện theo quy định của Chính phủ quy định chi tiết một số điều của Luật Đầu tư theo phương\nthức đối tác công tư.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P2',
#    'text': '2. Đối với dự án không thuộc trường hợp quy định tại khoản 1 Điều này, trình tự, thủ tục lập, thẩm định\nbáo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư, quyết định chủ trương đầu tư dự án\nBT thực hiện theo quy định của Chính phủ quy định chi tiết một số điều của Luật Đầu tư theo phương\nthức đối tác công tư.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5',
#    'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5',
#     'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#     'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#    'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#    'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#     'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPa',
#     'text': 'a) Sự cần thiết đầu tư; lợi thế đầu tư theo phương thức đối tác công tư, loại hợp đồng dự án BT; đánh\ngiá sơ bộ tác động môi trường theo quy định của pháp luật về bảo vệ môi trường như quy định đối với\ndự án đầu tư công (báo cáo đề xuất chủ trương đầu tư không phải thực hiện nội dung này);'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPa',
#    'text': 'a) Sự cần thiết đầu tư; lợi thế đầu tư theo phương thức đối tác công tư, loại hợp đồng dự án BT; đánh\ngiá sơ bộ tác động môi trường theo quy định của pháp luật về bảo vệ môi trường như quy định đối với\ndự án đầu tư công (báo cáo đề xuất chủ trương đầu tư không phải thực hiện nội dung này);'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#    'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#     'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPb',
#     'text': 'b) Mục tiêu; quy mô, địa điểm thực hiện dự án; thời gian, tiến độ xây dựng công trình dự án BT và thời\nhạn hợp đồng dự án; nhu cầu sử dụng đất và tài nguyên khác để thực hiện công trình dự án BT (nếu\ncó), không bao gồm nhu cầu sử dụng đất để dự kiến thanh toán cho nhà đầu tư;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPb',
#    'text': 'b) Mục tiêu; quy mô, địa điểm thực hiện dự án; thời gian, tiến độ xây dựng công trình dự án BT và thời\nhạn hợp đồng dự án; nhu cầu sử dụng đất và tài nguyên khác để thực hiện công trình dự án BT (nếu\ncó), không bao gồm nhu cầu sử dụng đất để dự kiến thanh toán cho nhà đầu tư;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#    'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#     'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPc',
#     'text': 'c) Phương án thiết kế sơ bộ theo quy định của pháp luật về xây dựng; thuyết minh sơ bộ về phương án\nkỹ thuật, công nghệ; sơ bộ phân chia dự án thành phần (nếu có);'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPc',
#    'text': 'c) Phương án thiết kế sơ bộ theo quy định của pháp luật về xây dựng; thuyết minh sơ bộ về phương án\nkỹ thuật, công nghệ; sơ bộ phân chia dự án thành phần (nếu có);'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#    'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#     'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPd',
#     'text': 'd) Sơ bộ hiệu quả kinh tế - xã hội của dự án; tác động của việc thực hiện dự án đối với cộng đồng, dân\ncư trong phạm vi dự án;\nđ) Sơ bộ tổng mức đầu tư công trình dự án BT;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPd',
#    'text': 'd) Sơ bộ hiệu quả kinh tế - xã hội của dự án; tác động của việc thực hiện dự án đối với cộng đồng, dân\ncư trong phạm vi dự án;\nđ) Sơ bộ tổng mức đầu tư công trình dự án BT;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#    'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5_P3',
#     'text': '3. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nquỹ đất gồm các nội dung cơ bản sau đây:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPe',
#     'text': 'e) Dự kiến phương thức thanh toán cho nhà đầu tư, trong đó xác định cụ thể vị trí, diện tích, giá trị dự\nkiến của quỹ đất dự kiến thanh toán theo quy định tại Điều 6 của Nghị định này.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P3_SPe',
#    'text': 'e) Dự kiến phương thức thanh toán cho nhà đầu tư, trong đó xác định cụ thể vị trí, diện tích, giá trị dự\nkiến của quỹ đất dự kiến thanh toán theo quy định tại Điều 6 của Nghị định này.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5',
#    'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5',
#     'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P4',
#     'text': '4. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nngân sách nhà nước gồm những nội dung quy định tại các điểm a, b, c, d và đ khoản 3 Điều này và nội\ndung sau:'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P4',
#    'text': '4. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nngân sách nhà nước gồm những nội dung quy định tại các điểm a, b, c, d và đ khoản 3 Điều này và nội\ndung sau:'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5_P4',
#    'text': '4. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nngân sách nhà nước gồm những nội dung quy định tại các điểm a, b, c, d và đ khoản 3 Điều này và nội\ndung sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5_P4',
#     'text': '4. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nngân sách nhà nước gồm những nội dung quy định tại các điểm a, b, c, d và đ khoản 3 Điều này và nội\ndung sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P4_SPa',
#     'text': 'a) Dự kiến phương thức, giá trị thanh toán đối với trường hợp thanh toán từ nguồn vốn đầu tư công;'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P4_SPa',
#    'text': 'a) Dự kiến phương thức, giá trị thanh toán đối với trường hợp thanh toán từ nguồn vốn đầu tư công;'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5_P4',
#    'text': '4. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nngân sách nhà nước gồm những nội dung quy định tại các điểm a, b, c, d và đ khoản 3 Điều này và nội\ndung sau:'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5_P4',
#     'text': '4. Báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư của dự án BT thanh toán bằng\nngân sách nhà nước gồm những nội dung quy định tại các điểm a, b, c, d và đ khoản 3 Điều này và nội\ndung sau:'},
#    'HAS_SUBPOINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P4_SPb',
#     'text': 'b) Vị trí, diện tích của quỹ đất, tài sản công dự kiến đấu giá đối với trường hợp thanh toán từ nguồn thu\nđược sau đấu giá theo quy định tại Điều 7 của Nghị định này.'}),
#   'm': {'id': '256/2025/NĐ-CP_chapter_II_C5_P4_SPb',
#    'text': 'b) Vị trí, diện tích của quỹ đất, tài sản công dự kiến đấu giá đối với trường hợp thanh toán từ nguồn thu\nđược sau đấu giá theo quy định tại Điều 7 của Nghị định này.'}},
#  {'n': {'id': '256/2025/NĐ-CP_chapter_II_C5',
#    'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#   'r': ({'id': '256/2025/NĐ-CP_chapter_II_C5',
#     'text': 'Điều 5. Lập, thẩm định báo cáo nghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư,\nquyết định chủ trương đầu tư'},
#    'HAS_POINT',
#    {'id': '256/2025/NĐ-CP_chapter_II_C5_P5',
#     'text': '5. Đối với dự án BT kết hợp thanh toán bằng quỹ đất và ngân sách nhà nước, cơ quan có thẩm quyền\nxác định hạng mục thanh toán bằng quỹ đất, hạng mục thanh toán bằng ngân sách nhà nước. Báo cáo\nnghiên cứu tiền khả thi, báo cáo đề xuất chủ trương đầu tư gồm các nội dung theo quy định tại khoản 3\nvà khoản 4 Điều này.'}),
# ...
#   'r': ({'id': '64/2020/QH14_chapter_VI_C74',
#     'text': 'Điều 74. Lập kế hoạch vốn đầu tư công sử dụng trong dự án PPP\nViệc lập kế hoạch vốn đầu tư công sử dụng trong dự án PPP được quy định như sau:'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C74_P4',
#     'text': '4. Trường hợp dự án PPP áp dụng loại hợp đồng BTL, hợp đồng BLT sử dụng vốn đầu tư công để\nthanh toán cho doanh nghiệp dự án PPP, việc tổng hợp vốn đầu tư công trong kế hoạch đầu tư công\ntrung hạn và hằng năm thực hiện theo quy định tại khoản 1 và khoản 2 Điều này. Căn cứ thời hạn hợp\nđồng dự án PPP, phần vốn đầu tư công được tiếp tục bố trí trong các kỳ trung hạn tiếp theo.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C74_P4',
#    'text': '4. Trường hợp dự án PPP áp dụng loại hợp đồng BTL, hợp đồng BLT sử dụng vốn đầu tư công để\nthanh toán cho doanh nghiệp dự án PPP, việc tổng hợp vốn đầu tư công trong kế hoạch đầu tư công\ntrung hạn và hằng năm thực hiện theo quy định tại khoản 1 và khoản 2 Điều này. Căn cứ thời hạn hợp\nđồng dự án PPP, phần vốn đầu tư công được tiếp tục bố trí trong các kỳ trung hạn tiếp theo.'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI',
#    'text': 'NGUỒN VỐN THỰC HIỆN DỰ ÁN PPP\nMục 1. VỐN NHÀ NƯỚC TRONG DỰ ÁN PPP',
#    'title': 'Chương VI'},
#   'r': ({'id': '64/2020/QH14_chapter_VI',
#     'text': 'NGUỒN VỐN THỰC HIỆN DỰ ÁN PPP\nMục 1. VỐN NHÀ NƯỚC TRONG DỰ ÁN PPP',
#     'title': 'Chương VI'},
#    'HAS_CLAUSE',
#    {'id': '64/2020/QH14_chapter_VI_C75',
#     'text': 'Điều 75. Lập dự toán nguồn vốn chi thường xuyên và nguồn thu hợp pháp dành để chi thường\nxuyên của các cơ quan nhà nước, đơn vị sự nghiệp công lập'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C75',
#    'text': 'Điều 75. Lập dự toán nguồn vốn chi thường xuyên và nguồn thu hợp pháp dành để chi thường\nxuyên của các cơ quan nhà nước, đơn vị sự nghiệp công lập'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C75',
#    'text': 'Điều 75. Lập dự toán nguồn vốn chi thường xuyên và nguồn thu hợp pháp dành để chi thường\nxuyên của các cơ quan nhà nước, đơn vị sự nghiệp công lập'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C75',
#     'text': 'Điều 75. Lập dự toán nguồn vốn chi thường xuyên và nguồn thu hợp pháp dành để chi thường\nxuyên của các cơ quan nhà nước, đơn vị sự nghiệp công lập'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C75_P1',
#     'text': '1. Căn cứ quyết định chủ trương đầu tư, báo cáo nghiên cứu khả thi được cấp có thẩm quyền phê duyệt\nvà kết quả lựa chọn nhà đầu tư, cơ quan ký kết hợp đồng lập dự toán ngân sách hằng năm đối với\nnguồn vốn chi thường xuyên, nguồn thu hợp pháp dành để chi thường xuyên của các cơ quan nhà nước,\nđơn vị sự nghiệp công lập để thanh toán cho doanh nghiệp dự án PPP theo quy định của pháp luật về\nngân sách nhà nước.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C75_P1',
#    'text': '1. Căn cứ quyết định chủ trương đầu tư, báo cáo nghiên cứu khả thi được cấp có thẩm quyền phê duyệt\nvà kết quả lựa chọn nhà đầu tư, cơ quan ký kết hợp đồng lập dự toán ngân sách hằng năm đối với\nnguồn vốn chi thường xuyên, nguồn thu hợp pháp dành để chi thường xuyên của các cơ quan nhà nước,\nđơn vị sự nghiệp công lập để thanh toán cho doanh nghiệp dự án PPP theo quy định của pháp luật về\nngân sách nhà nước.'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C75',
#    'text': 'Điều 75. Lập dự toán nguồn vốn chi thường xuyên và nguồn thu hợp pháp dành để chi thường\nxuyên của các cơ quan nhà nước, đơn vị sự nghiệp công lập'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C75',
#     'text': 'Điều 75. Lập dự toán nguồn vốn chi thường xuyên và nguồn thu hợp pháp dành để chi thường\nxuyên của các cơ quan nhà nước, đơn vị sự nghiệp công lập'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C75_P2',
#     'text': '2. Đối với khoản chi thường xuyên quy định tại khoản 3 Điều 73 của Luật này , cơ quan có thẩm quyền,\ncơ quan ký kết hợp đồng lập dự toán ngân sách hằng năm, trình cấp có thẩm quyền phê duyệt theo quy\nđịnh của pháp luật về ngân sách nhà nước.\nMục 2. VỐN THỰC HIỆN DỰ ÁN PPP CỦA NHÀ ĐẦU TƯ, DOANH NGHIỆP DỰ ÁN PPP'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C75_P2',
#    'text': '2. Đối với khoản chi thường xuyên quy định tại khoản 3 Điều 73 của Luật này , cơ quan có thẩm quyền,\ncơ quan ký kết hợp đồng lập dự toán ngân sách hằng năm, trình cấp có thẩm quyền phê duyệt theo quy\nđịnh của pháp luật về ngân sách nhà nước.\nMục 2. VỐN THỰC HIỆN DỰ ÁN PPP CỦA NHÀ ĐẦU TƯ, DOANH NGHIỆP DỰ ÁN PPP'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI',
#    'text': 'NGUỒN VỐN THỰC HIỆN DỰ ÁN PPP\nMục 1. VỐN NHÀ NƯỚC TRONG DỰ ÁN PPP',
#    'title': 'Chương VI'},
#   'r': ({'id': '64/2020/QH14_chapter_VI',
#     'text': 'NGUỒN VỐN THỰC HIỆN DỰ ÁN PPP\nMục 1. VỐN NHÀ NƯỚC TRONG DỰ ÁN PPP',
#     'title': 'Chương VI'},
#    'HAS_CLAUSE',
#    {'id': '64/2020/QH14_chapter_VI_C76',
#     'text': 'Điều 76. Thu xếp tài chính thực hiện dự án PPP'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C76',
#    'text': 'Điều 76. Thu xếp tài chính thực hiện dự án PPP'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C76',
#    'text': 'Điều 76. Thu xếp tài chính thực hiện dự án PPP'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C76',
#     'text': 'Điều 76. Thu xếp tài chính thực hiện dự án PPP'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C76_P1',
#     'text': '1. Nhà đầu tư, doanh nghiệp dự án PPP chịu trách nhiệm góp vốn chủ sở hữu, huy động vốn vay và các\nnguồn vốn hợp pháp khác để thực hiện dự án theo quy định tại hợp đồng dự án PPP. Tổng số vốn vay\nthông qua các hình thức vay không vượt quá tổng số vốn vay quy định tại hợp đồng dự án PPP.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C76_P1',
#    'text': '1. Nhà đầu tư, doanh nghiệp dự án PPP chịu trách nhiệm góp vốn chủ sở hữu, huy động vốn vay và các\nnguồn vốn hợp pháp khác để thực hiện dự án theo quy định tại hợp đồng dự án PPP. Tổng số vốn vay\nthông qua các hình thức vay không vượt quá tổng số vốn vay quy định tại hợp đồng dự án PPP.'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C76',
#    'text': 'Điều 76. Thu xếp tài chính thực hiện dự án PPP'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C76',
#     'text': 'Điều 76. Thu xếp tài chính thực hiện dự án PPP'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C76_P2',
#     'text': '2. Trong thời hạn 12 tháng kể từ ngày ký kết hợp đồng, nhà đầu tư, doanh nghiệp dự án PPP phải hoàn\nthành thu xếp tài chính; đối với dự án thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội\nhoặc Thủ tướng Chính phủ thì thời hạn này có thể kéo dài nhưng không quá 18 tháng.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C76_P2',
#    'text': '2. Trong thời hạn 12 tháng kể từ ngày ký kết hợp đồng, nhà đầu tư, doanh nghiệp dự án PPP phải hoàn\nthành thu xếp tài chính; đối với dự án thuộc thẩm quyền quyết định chủ trương đầu tư của Quốc hội\nhoặc Thủ tướng Chính phủ thì thời hạn này có thể kéo dài nhưng không quá 18 tháng.'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C76',
#    'text': 'Điều 76. Thu xếp tài chính thực hiện dự án PPP'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C76',
#     'text': 'Điều 76. Thu xếp tài chính thực hiện dự án PPP'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C76_P3',
#     'text': '3. Hình thức xử lý trong trường hợp nhà đầu tư, doanh nghiệp dự án PPP không thu xếp được tài chính\ntheo thời hạn quy định tại khoản 2 Điều này phải được quy định tại hồ sơ mời thầu.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C76_P3',
#    'text': '3. Hình thức xử lý trong trường hợp nhà đầu tư, doanh nghiệp dự án PPP không thu xếp được tài chính\ntheo thời hạn quy định tại khoản 2 Điều này phải được quy định tại hồ sơ mời thầu.'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI',
#    'text': 'NGUỒN VỐN THỰC HIỆN DỰ ÁN PPP\nMục 1. VỐN NHÀ NƯỚC TRONG DỰ ÁN PPP',
#    'title': 'Chương VI'},
#   'r': ({'id': '64/2020/QH14_chapter_VI',
#     'text': 'NGUỒN VỐN THỰC HIỆN DỰ ÁN PPP\nMục 1. VỐN NHÀ NƯỚC TRONG DỰ ÁN PPP',
#     'title': 'Chương VI'},
#    'HAS_CLAUSE',
#    {'id': '64/2020/QH14_chapter_VI_C77',
#     'text': 'Điều 77. Góp vốn chủ sở hữu'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C77',
#    'text': 'Điều 77. Góp vốn chủ sở hữu'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C77',
#    'text': 'Điều 77. Góp vốn chủ sở hữu'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C77',
#     'text': 'Điều 77. Góp vốn chủ sở hữu'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C77_P1',
#     'text': '1. Nhà đầu tư phải góp vốn chủ sở hữu tối thiểu là 15% tổng mức đầu tư dự án không bao gồm vốn nhà\nnước quy định tại Điều 70 và Điều 72 của Luật này .'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C77_P1',
#    'text': '1. Nhà đầu tư phải góp vốn chủ sở hữu tối thiểu là 15% tổng mức đầu tư dự án không bao gồm vốn nhà\nnước quy định tại Điều 70 và Điều 72 của Luật này .'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C77',
#    'text': 'Điều 77. Góp vốn chủ sở hữu'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C77',
#     'text': 'Điều 77. Góp vốn chủ sở hữu'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C77_P2',
#     'text': '2. Nhà đầu tư phải góp vốn chủ sở hữu theo tiến độ thỏa thuận tại hợp đồng dự án PPP.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C77_P2',
#    'text': '2. Nhà đầu tư phải góp vốn chủ sở hữu theo tiến độ thỏa thuận tại hợp đồng dự án PPP.'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI',
#    'text': 'NGUỒN VỐN THỰC HIỆN DỰ ÁN PPP\nMục 1. VỐN NHÀ NƯỚC TRONG DỰ ÁN PPP',
#    'title': 'Chương VI'},
#   'r': ({'id': '64/2020/QH14_chapter_VI',
#     'text': 'NGUỒN VỐN THỰC HIỆN DỰ ÁN PPP\nMục 1. VỐN NHÀ NƯỚC TRONG DỰ ÁN PPP',
#     'title': 'Chương VI'},
#    'HAS_CLAUSE',
#    {'id': '64/2020/QH14_chapter_VI_C78',
#     'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C78',
#    'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C78',
#    'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C78',
#     'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C78_P1',
#     'text': '1. Doanh nghiệp dự án PPP được phát hành, mua lại trái phiếu riêng lẻ do mình đã phát hành theo quy\nđịnh của Luật này, pháp luật về doanh nghiệp, chứng khoán để huy động vốn thực hiện dự án PPP;\nkhông được phát hành trái phiếu chuyển đổi riêng lẻ và trái phiếu kèm chứng quyền riêng lẻ.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C78_P1',
#    'text': '1. Doanh nghiệp dự án PPP được phát hành, mua lại trái phiếu riêng lẻ do mình đã phát hành theo quy\nđịnh của Luật này, pháp luật về doanh nghiệp, chứng khoán để huy động vốn thực hiện dự án PPP;\nkhông được phát hành trái phiếu chuyển đổi riêng lẻ và trái phiếu kèm chứng quyền riêng lẻ.'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C78',
#    'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C78',
#     'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C78_P2',
#     'text': '2. Việc phát hành trái phiếu theo quy định tại khoản 1 Điều này phải đáp ứng các điều kiện sau đây:'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C78_P2',
#    'text': '2. Việc phát hành trái phiếu theo quy định tại khoản 1 Điều này phải đáp ứng các điều kiện sau đây:'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C78_P2',
#    'text': '2. Việc phát hành trái phiếu theo quy định tại khoản 1 Điều này phải đáp ứng các điều kiện sau đây:'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C78_P2',
#     'text': '2. Việc phát hành trái phiếu theo quy định tại khoản 1 Điều này phải đáp ứng các điều kiện sau đây:'},
#    'HAS_SUBPOINT',
#    {'id': '64/2020/QH14_chapter_VI_C78_P2_SPa',
#     'text': 'a) Số vốn huy động thông qua phát hành trái phiếu không vượt quá giá trị phần vốn vay được xác định\ntại hợp đồng dự án PPP;'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C78_P2_SPa',
#    'text': 'a) Số vốn huy động thông qua phát hành trái phiếu không vượt quá giá trị phần vốn vay được xác định\ntại hợp đồng dự án PPP;'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C78_P2',
#    'text': '2. Việc phát hành trái phiếu theo quy định tại khoản 1 Điều này phải đáp ứng các điều kiện sau đây:'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C78_P2',
#     'text': '2. Việc phát hành trái phiếu theo quy định tại khoản 1 Điều này phải đáp ứng các điều kiện sau đây:'},
#    'HAS_SUBPOINT',
#    {'id': '64/2020/QH14_chapter_VI_C78_P2_SPb',
#     'text': 'b) Vốn huy động thông qua phát hành trái phiếu không được sử dụng cho bất kỳ mục đích nào khác\nngoài mục đích thực hiện dự án theo hợp đồng dự án PPP hoặc cho việc cơ cấu lại các khoản nợ của\ndoanh nghiệp;'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C78_P2_SPb',
#    'text': 'b) Vốn huy động thông qua phát hành trái phiếu không được sử dụng cho bất kỳ mục đích nào khác\nngoài mục đích thực hiện dự án theo hợp đồng dự án PPP hoặc cho việc cơ cấu lại các khoản nợ của\ndoanh nghiệp;'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C78_P2',
#    'text': '2. Việc phát hành trái phiếu theo quy định tại khoản 1 Điều này phải đáp ứng các điều kiện sau đây:'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C78_P2',
#     'text': '2. Việc phát hành trái phiếu theo quy định tại khoản 1 Điều này phải đáp ứng các điều kiện sau đây:'},
#    'HAS_SUBPOINT',
#    {'id': '64/2020/QH14_chapter_VI_C78_P2_SPc',
#     'text': 'c) Doanh nghiệp dự án PPP phải mở tài khoản phong tỏa để nhận tiền mua trái phiếu. Việc giải ngân\nvốn từ phát hành trái phiếu thực hiện theo quy định tại điểm b khoản này.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C78_P2_SPc',
#    'text': 'c) Doanh nghiệp dự án PPP phải mở tài khoản phong tỏa để nhận tiền mua trái phiếu. Việc giải ngân\nvốn từ phát hành trái phiếu thực hiện theo quy định tại điểm b khoản này.'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C78',
#    'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C78',
#     'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C78_P3',
#     'text': '3. Doanh nghiệp dự án PPP hoạt động chưa đủ thời gian 01 năm thì khi phát hành trái phiếu theo quy\nđịnh tại khoản 1 Điều này được miễn điều kiện có báo cáo tài chính của năm trước liền kề năm phát\nhành được kiểm toán theo quy định của pháp luật về doanh nghiệp.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C78_P3',
#    'text': '3. Doanh nghiệp dự án PPP hoạt động chưa đủ thời gian 01 năm thì khi phát hành trái phiếu theo quy\nđịnh tại khoản 1 Điều này được miễn điều kiện có báo cáo tài chính của năm trước liền kề năm phát\nhành được kiểm toán theo quy định của pháp luật về doanh nghiệp.'}},
#  {'n': {'id': '64/2020/QH14_chapter_VI_C78',
#    'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'},
#   'r': ({'id': '64/2020/QH14_chapter_VI_C78',
#     'text': 'Điều 78. Phát hành trái phiếu của doanh nghiệp dự án PPP'},
#    'HAS_POINT',
#    {'id': '64/2020/QH14_chapter_VI_C78_P4',
#     'text': '4. Chính phủ quy định chi tiết Điều này.'}),
#   'm': {'id': '64/2020/QH14_chapter_VI_C78_P4',
#    'text': '4. Chính phủ quy định chi tiết Điều này.'}},
#  {'n': {'amendment_history': 'None',
#    'law_id': '64/2020/QH14',
#    'issuer_department': 'Quốc Hội',
#    'issue_date': '18/06/2020',
#    'jurisdiction_scope': 'National',
#    'location': 'Hà Nội',
#    'title': 'Luật Đầu Tư Theo Phương',
#    'issuer': 'Nguyễn Thị Kim Ngân',
#    'document_type': 'Luật'},
#   'r': ({'amendment_history': 'None',
#     'law_id': '64/2020/QH14',
#     'issuer_department': 'Quốc Hội',
#     'issue_date': '18/06/2020',
#     'jurisdiction_scope': 'National',
#     'location': 'Hà Nội',
#     'title': 'Luật Đầu Tư Theo Phương',
#     'issuer': 'Nguyễn Thị Kim Ngân',
#     'document_type': 'Luật'},
#    'HAS_CHAPTER',
#    {'id': '64/2020/QH14_chapter_VII',
#     'text': 'ƯU ĐÃI VÀ BẢO ĐẢM ĐẦU TƯ',
#     'title': 'Chương VII'}),
#   'm': {'id': '64/2020/QH14_chapter_VII',
#    'text': 'ƯU ĐÃI VÀ BẢO ĐẢM ĐẦU TƯ',
#    'title': 'Chương VII'}},
#  ...]
